# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pylab as plt
plt.rcParams['figure.figsize'] = (12, 8)

# %%
training = pd.read_csv('C:/Users/MANOJ/occupancy_detection/Occupancy-detection-data-luis/datatraining.txt')
training['date'] = pd.to_datetime(training.date,format='%Y-%m-%d %H:%M:%S')
training.set_index(training['date'],drop=True,inplace=True)
del training['date']

# %%
target_name = 'Occupancy'
features = training[[col for col in training.columns if col not in target_name]]
target = training[[target_name]]

# %%
# %run functions.ipynb
# %run machine_learn_script.ipynb

# %%
plot_correlation(training)

# %%
learn_instance = learn(features,target,cv=10)

# %%
prediction_frame_rdf, cv_rdf, mbe_rdf, r2_rdf = learn_instance.rdf(cross_validate=True)
# Out:
# coefficient of variance = 71.97
# Mean bias error = 19.49
# R Squared = 0.860
